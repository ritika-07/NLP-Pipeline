# %% [markdown]
# # Step 9: Coreference Resolution

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm_notebook

# %%
MODEL_URL = "https://github.com/huggingface/neuralcoref-models/releases/" \
            "download/en_coref_md-3.0.0/en_coref_md-3.0.0.tar.gz"

# %%
# !pip install spacy==2.0.12
# Out:
# Requirement already satisfied: spacy==2.0.12 in /opt/conda/lib/python3.6/site-packages (2.0.12)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (0.9.6)
# Requirement already satisfied: cymem<1.32,>=1.30 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (1.31.2)
# Requirement already satisfied: numpy>=1.7 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (1.16.0)
# Requirement already satisfied: regex==2017.4.5 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (2017.4.5)
# Requirement already satisfied: ujson>=1.35 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (1.35)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (1.0.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (6.10.3)
# Requirement already satisfied: dill<0.3,>=0.2 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (0.2.8.2)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (0.28.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.6/site-packages (from spacy==2.0.12) (2.21.0)
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.5.6)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.9.0.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (1.10.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (4.29.1)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.4.3.2)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (1.22)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.9.0)
# You are using pip version 18.1, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install {MODEL_URL}
# Out:
# Collecting https://github.com/huggingface/neuralcoref-models/releases/download/en_coref_md-3.0.0/en_coref_md-3.0.0.tar.gz
#   Downloading https://github.com/huggingface/neuralcoref-models/releases/download/en_coref_md-3.0.0/en_coref_md-3.0.0.tar.gz (161.3MB)
#     100% |████████████████████████████████| 161.3MB 160kB/s eta 0:00:01 4% |█▎                              | 6.5MB 31.8MB/s eta 0:00:05    46% |███████████████                 | 75.2MB 57.0MB/s eta 0:00:02    73% |███████████████████████▌        | 118.4MB 52.7MB/s eta 0:00:01    79% |█████████████████████████▎      | 127.7MB 53.8MB/s eta 0:00:01
# Requirement already satisfied (use --upgrade to upgrade): en-coref-md==3.0.0 from https://github.com/huggingface/neuralcoref-models/releases/download/en_coref_md-3.0.0/en_coref_md-3.0.0.tar.gz in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: spacy>=>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from en-coref-md==3.0.0) (2.0.12)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (1.0.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (6.10.3)
# Requirement already satisfied: regex==2017.4.5 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (2017.4.5)
# Requirement already satisfied: numpy>=1.7 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (1.16.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (0.9.6)
# Requirement already satisfied: cymem<1.32,>=1.30 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (1.31.2)
# Requirement already satisfied: ujson>=1.35 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (1.35)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (0.28.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (0.2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.6/site-packages (from spacy>=>=2.0.0->en-coref-md==3.0.0) (2.21.0)
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (0.5.6)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (0.4.3.2)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (0.9.0.1)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (1.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (4.29.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (1.10.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=>=2.0.0->en-coref-md==3.0.0) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=>=2.0.0->en-coref-md==3.0.0) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=>=2.0.0->en-coref-md==3.0.0) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=>=2.0.0->en-coref-md==3.0.0) (3.0.4)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy>=>=2.0.0->en-coref-md==3.0.0) (0.9.0)
# Building wheels for collected packages: en-coref-md
#   Running setup.py bdist_wheel for en-coref-md ... done
#   Stored in directory: /root/.cache/pip/wheels/aa/a3/8f/9df13c027b75169bcca62682563e9823bb213c72a2cc3efed8
# Successfully built en-coref-md
# You are using pip version 18.1, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !python -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: en_core_web_md==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz#egg=en_core_web_md==2.0.0 in /opt/conda/lib/python3.6/site-packages (2.0.0)
# You are using pip version 18.1, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /opt/conda/lib/python3.6/site-packages/en_core_web_md -->
#     /opt/conda/lib/python3.6/site-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %%
import en_coref_md

nlp = en_coref_md.load()

# %%
about_text = """Christmas is celebrated as the birthday of Jesus. It is celebrated on 25 December every year. It is the most important festival of the Christians. 
One of the major attractions of the Christmas festival is the Christmas Tree. A Christmas Tree is a decorated tree. 
It is usually an evergreen conifer traditionally associated with the celebration of Christmas. Candles, toffees and cakes are tied with ribbon and paper napkins to the tree. 
The Christmas Tree in ancient times was considered a symbol of the continuity of life. 
It is believed that evil spirits stay away from the house and keep the flow of positive energy. 
They are available in many sizes in the market. A person disguised as Santa Claus distributes sweets among the children. 
Family reunions and the exchange of gifts are a widespread feature of the season. Children get dressed in new clothes. Prayers are offered in churches."""
doc = nlp(about_text)

# %%
doc._.has_coref
# Out:
# True

# %%
doc._.coref_clusters
# Out:
# [Christmas: [Christmas, It, It, the Christmas festival],
#  the Christmas Tree: [the Christmas Tree, A Christmas Tree, It, the tree, The Christmas Tree in ancient times, It],
#  evil spirits stay away from the house and keep the flow of positive energy: [evil spirits stay away from the house and keep the flow of positive energy, They]]
